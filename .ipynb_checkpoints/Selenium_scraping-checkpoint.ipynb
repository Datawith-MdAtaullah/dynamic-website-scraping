# %% [markdown]
# ## ***Selenium Automation + Web Crawling***

# %%
from selenium import webdriver
import time

website = 'https://www.adamchoi.co.uk/teamgoals/detailed'

driver = webdriver.Chrome()

driver.get(website)

time.sleep(5)

driver.quit()

# %%
# using options for modern selenium 

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time 

# setup chrome options

options = Options()
options.add_argument("--start-maximized")  # open window full screen
options.add_argument("--disable-infobars")
options.add_argument("--disable-extensions")

driver = webdriver.Chrome(options=options)

website = 'https://www.adamchoi.co.uk/teamgoals/detailed'

driver.get(website)

time.sleep(5)

driver.quit()

# %% [markdown]
# #### ***WebDriver-Manager***

# %%
# automatically detects chrome version 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

print('started')

#setup options 

options = Options()
options.add_argument('--headless=new')
print('running headlessly')

#setup chrome driver via webdriver-manager

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

website = 'https://www.adamchoi.co.uk/teamgoals/detailed'

driver.get(website)

time.sleep(5)

driver.quit()

print('closed')
# Out:
# started
# running headlessly
# closed

# %%
# clicking on button via crating xpath and using that

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time 

# setup chrome options

options = Options()
options.add_argument("--start-maximized")  

# launch

driver = webdriver.Chrome(options=options)

website = 'https://www.adamchoi.co.uk/teamgoals/detailed'

driver.get(website)

all_matches_button = driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')

all_matches_button.click()

time.sleep(6)

driver.quit()

# %% [raw]
# #### Type	                      ##### ***Example usage***	                                                           #### When to use
#
# By.ID	                          driver.find_element(By.ID, "username")	                                           Fastest — if the element has a unique id
# By.NAME	                          driver.find_element(By.NAME, "email")	                                               When elements have a name attribute
# By.CLASS_NAME	                  driver.find_element(By.CLASS_NAME, "btn-primary")	                                   When class names are unique
# By.CSS_SELECTOR	                  driver.find_element(By.CSS_SELECTOR, 'label[analytics-event="All matches"]')	       Powerful and modern; often cleaner than XPath
# By.XPATH	                      driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')	           Very flexible; works even when other attributes are missing
# By.LINK_TEXT	                  driver.find_element(By.LINK_TEXT, "Click here")	                                   For anchor (<a>) tags with visible text
# By.PARTIAL_LINK_TEXT	          driver.find_element(By.PARTIAL_LINK_TEXT, "Click")	                               When link text is partially known
# By.TAG_NAME	                      driver.find_element(By.TAG_NAME, "input")	                                           For generic tag lookups
#
# ##### *✅ Example — same element with CSS instead of XPath*
#
# Your line:
#
# all_matches_button = driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')
#
#
# can be rewritten using CSS like this:
#
# all_matches_button = driver.find_element(By.CSS_SELECTOR, 'label[analytics-event="All matches"]')

# %%
# clicking on button via crating xpath and using that

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time 

# setup chrome options

options = Options()
options.add_argument("--start-maximized")
options.add_argument('--headless=new')

# launch

driver = webdriver.Chrome(options=options)

website = 'https://www.adamchoi.co.uk/teamgoals/detailed'

driver.get(website)

all_matches_button = driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')

all_matches_button.click()

table_content = driver.find_element(By.TAG_NAME, 'tr')

print(table_content)

time.sleep(6)

driver.quit()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cbb78e9749d825fa86e4ede80fb9e9de", element="f.B57FC10E4911D9127F8C1F3E74F0A2D5.d.2F10C9E77C68E98321C0CA127B5D743F.e.93")>
